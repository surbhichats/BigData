# %%
"""
This module is the spark streaming analysis process.


Usage:
    If used with dataproc:
        gcloud dataproc jobs submit pyspark --cluster <Cluster Name> twitterHTTPClient.py

    Create a dataset in BigQurey first using
        bq mk bigdata_sparkStreaming

    Remeber to replace the bucket with your own bucket name


Todo:
    1. hashtagCount: calculate accumulated hashtags count
    2. wordCount: calculate word count every 60 seconds
        the word you should track is listed below.
    3. save the result to google BigQuery

"""

import subprocess
import time

from pyspark import SparkConf, SparkContext
from pyspark.sql import SQLContext
from pyspark.streaming import StreamingContext

# global variables
bucket = 'surbhi-mis586-asgnmt4'  # TODO: here, replace with your own bucket name
output_directory_hashtags = 'gs://{}/hadoop/tmp/bigquery/pyspark_output/hashtagsCount'.format(
    bucket)
output_directory_wordcount = 'gs://{}/hadoop/tmp/bigquery/pyspark_output/wordcount'.format(
    bucket)

# output table and columns name
output_dataset = 'dataset1'  #TODO: the name of your dataset in BigQuery
    # (Create a BigQuery dataset first using bq mk <your dataset name> in Google Cloud SDK Shell or any alternative approaches.)
output_table_hashtags = 'hashtags'
columns_name_hashtags = ['hashtags', 'count']
output_table_wordcount = 'wordcount'
columns_name_wordcount = ['word', 'count', 'time']

# parameter
IP = 'localhost'  # ip port
PORT = 9001  # port

STREAMTIME = 600  # time that the streaming process runs
#STREAMTIME = 20  # for test

WORD = ['data', 'spark', 'ai', 'movie', 'coronavirus']  # the words you should filter and do word count


# Helper functions
def saveToStorage(rdd, output_directory, columns_name, mode):
    """
    Save each RDD in this DStream to google storage
    Args:
        rdd: input rdd
        output_directory: output directory in google storage
        columns_name: columns name of dataframe
        mode: mode = "overwirte", overwirte the file
              mode = "append", append data to the end of file
    """
    if not rdd.isEmpty():
        (rdd.toDF(columns_name)
         .write.save(output_directory, format="json", mode=mode))


def saveToBigQuery(sc, output_dataset, output_table, directory):
    """
    Put temp streaming json files in google storage to google BigQuery
    and clean the output files in google storage
    """
    files = directory + '/part-*'
    subprocess.check_call(
        'bq load --source_format NEWLINE_DELIMITED_JSON '
        '--replace '
        '--autodetect '
        '{dataset}.{table} {files}'.format(
            dataset=output_dataset, table=output_table, files=files
        ).split())
    output_path = sc._jvm.org.apache.hadoop.fs.Path(directory)
    output_path.getFileSystem(sc._jsc.hadoopConfiguration()).delete(
        output_path, True)


def hashtagCount(words):
    """
    Calculate the accumulated hashtags count sum from the beginning of the stream
    and sort it by descending order of the count.
    Ignore case sensitivity when counting the hashtags:
        "#Ab" and "#ab" are considered to be a same hashtag
    You have to:
    1. Filter out the word that is hashtags.
       Hashtag usually start with "#" and followed by a serious of alphanumeric
    2. map (hashtag) to (hashtag, 1)
    3. sum the count of current DStream state and previous state
    4. transform unordered DStream to a ordered Dstream
    Hints:
        You may use regular expression to filter the words
        You can take a look at updateStateByKey and transform transformations
    Args:
        dstream(DStream): stream of real time tweets
    Returns:
        DStream Object with inner structure (hashtag, count)
    """
    
    # TODO: insert your code here
    # 0. Define a function called "updateFunc" compting running sum of hashtag counts:
    def updateFunc(new_values, last_sum):
        return sum(new_values) + (last_sum or 0)
    
    # 1. Define hashtag using the following techniques:
    #    1.1. "#Ab" and "#ab" are the same: hashtag = words.map(lambda x: x.lower())
    #    1.2. Filter out hashtags:  .filter(lambda x: len(x) > 2 and x[0] == "#")
    #    1.3. map (hashtag) to (hashtag, 1): .map(lambda x: (x, 1))
    hashtag = words.map(lambda x: x.lower()).filter(lambda x: len(x) > 2 and x[0] == "#").map(lambda x: (x, 1))
    # 2. Define hashtag count using reduceByKey
    hashtag_cnt = hashtag.reduceByKey(lambda cnt1, cnt2: cnt1 + cnt2)
    # 3. Update total hashtag count using updateStateByKey and the updateFunc defined above:
    hashtag_cnt_total = hashtag_cnt.updateStateByKey(updateFunc)
    # 4. Sort the hashtag counts using transform transformation:
    #       .transform(lambda rdd: rdd.sortBy(lambda x: x[1], ascending=False))
    hashtag_cnt_total = hashtag_cnt.updateStateByKey(updateFunc).transform(
        lambda rdd: rdd.sortBy(lambda x: x[1], ascending=False))
    # 5. Return total hashtag count:
    return hashtag_cnt_total


def wordCount(words):
    """
    Calculte the count of 5 sepcial words for every 60 seconds (window no overlap)
    You can choose your own words.
    Your should:
    1. filter the words
    2. count the word during a special window size
    3. add a time related mark to the output of each window, ex: a datetime type
    Hints:
        You can take a look at reduceByKeyAndWindow transformation
        Dstream is a serious of rdd, each RDD in a DStream contains data from a certain interval
        You may want to take a look of transform transformation of DStream when trying to add a time
    Args:
        dstream(DStream): stream of real time tweets
    Returns:
        DStream Object with inner structure (word, count, time)
    """
    
    # TODO: insert your code here
    # 1. Define word_cnt using the following techniques:
    #    1.1. "#Ab" and "#ab" are the same: word_cnt = words.map(lambda x: x.lower())
    #    1.2. Filter the words we want: .filter(lambda word: word in WORD)
    #    1.3. map (word) to (word, 1): .map(lambda x: (x, 1))
    #    1.4. Use reduceByKeyAndWindow transformation to count the word during a special window size: 
    #           .reduceByKeyAndWindow(lambda a, b: a + b, lambda a, b: a - b, 60, 60)
    word_cnt = words.map(lambda x: x.lower()).filter(lambda word: word in WORD).map(
        lambda x: (x, 1)).reduceByKeyAndWindow(lambda a, b: a + b, lambda a, b: a - b, 60, 60)
    # 2. Use transform and map transformations to update total word count by adding 
    #    date and time related mark to the output:
    word_cnt_total = word_cnt.transform(lambda time, rdd: rdd.map(
        lambda x: (x[0], x[1], time.strftime("%Y-%m-%d %H:%M:%S"))))
    
    return word_cnt_total


if __name__ == '__main__':
    # Spark settings
    conf = SparkConf()
    conf.setMaster('local[2]')
    conf.setAppName("TwitterStreamApp")

    # create spark context with the above configuration
    sc = SparkContext(conf=conf)
    sc.setLogLevel("ERROR")

    # create sql context, used for saving rdd
    sql_context = SQLContext(sc)

    # create the Streaming Context from the above spark context with batch interval size 60 seconds
    ssc = StreamingContext(sc, 60)
    #ssc = StreamingContext(sc, 5)
    # setting a checkpoint to allow RDD recovery
    ssc.checkpoint("~/checkpoint_TwitterApp")

    # read data from port 9001
    dataStream = ssc.socketTextStream(IP, PORT)
    dataStream.pprint()

    words = dataStream.flatMap(lambda line: line.split(" "))

    # calculate the accumulated hashtags count sum from the beginning of the stream
    topTags = hashtagCount(words)
    topTags.pprint()

    # calculte the word count during each time period 6s
    wordCount = wordCount(words)
    wordCount.pprint()

    """
    save hashtags count and word count to google storage
    used to save to google BigQuery
    You should:
      1. topTags: only save the lastest rdd in DStream
      2. wordCount: save each rdd in DStream
    Hints:
      1. You can take a look at foreachRDD transformation
      2. You may want to use helper function saveToStorage
      3. You should use save output to output_directory_hashtags, output_directory_wordcount,
         and have output columns name columns_name_hashtags and columns_name_wordcount.    
    """
    # TODO: insert your code here
    # 0. Use foreachRDD transformation and saveToStorage helper function to 
    #    save hashtags count to google storage: 
    topTags.foreachRDD(lambda rdd: saveToStorage(rdd, output_directory_hashtags, 
                                                 columns_name_hashtags, mode="overwrite"))
    # 1. Use foreachRDD transformation and saveToStorage helper function to 
    #    save word count to google storage:
    wordCount.foreachRDD(lambda rdd: saveToStorage(rdd, output_directory_wordcount,
                                                   columns_name_wordcount, mode="append"))
    
    # start streaming process, wait for 600s and then stop.
    ssc.start()
    time.sleep(STREAMTIME)
    ssc.stop(stopSparkContext=False, stopGraceFully=True)
    print("Running Finished.")
    
    # put the temp result in google storage to google BigQuery
    saveToBigQuery(sc, output_dataset, output_table_hashtags, output_directory_hashtags)
    saveToBigQuery(sc, output_dataset, output_table_wordcount, output_directory_wordcount)
    print("Saved To BigQuery Finished.")
# Out:
# -------------------------------------------
# Time: 2020-04-03 05:22:00
# -------------------------------------------
# RT @fructosepapi: “funny how bitches turn into my fans”WHAT ABOUT EUIWOONG ANG HYEONGSEOPRT @RBReich: Jeff Bezos' LA mansion has:
#
# —3 saunas
# —2 guesthouses
# —A golf course
# —A tennis court
# —A "motor court" with gas pumps
#
# His DC m…RT @KamalaHarris: Fifty days ago I attended a Homeland Security committee meeting about the coronavirus—and no current Trump administration…RT @Emily_Baum: NEW: Two months before the novel coronavirus likely began spreading in Wuhan, the Trump administration ended a $200-million…RT @BeVipul: #Corona_Jihad ? Over the world. https://t.co/7MGR662EOVRT @JoyceWhiteVance: This brave man tried to protect his sailors at the cost of his own career. He should be getting a medal not a demotion…Humanity before anything else. #OneWorldOneFight ❤️RT @AskAnshul: This person is now arrested in Maharashtra.
#
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:22:00
# -------------------------------------------
# ('#coronavirus', 8)
# ('#corona_jihad', 1)
# ('#brettcrozier', 1)
# ('#caronavirusindia', 1)
# ('#stayhomesavelives', 1)
# ('#lockdown', 1)
# ('#oil', 1)
# ('#byomkeshbakshi', 1)
# ('#9baje9minutes', 1)
# ('#sooraraipottru', 1)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:22:00
# -------------------------------------------
# ('movie', 8, '2020-04-03 05:22:00')
# ('ai', 1, '2020-04-03 05:22:00')
# ('coronavirus', 51, '2020-04-03 05:22:00')
#
# -------------------------------------------
# Time: 2020-04-03 05:23:00
# -------------------------------------------
# Japanese Prime Minister Shinzo Abe… https://t.co/ZHIP9G55rd@AdamHSays Written sometime between the spring of 1982 and early 1983-before the movie had a director, a screenwrit… https://t.co/vFn0DFREfcThe caronavirus is serious but these two 🤣🤣🤣🤣RT @vonderleyen: The European Union thanks Taiwan for its donation of 5.6 million masks to help fight the #coronavirus. We really appreciat…RT @Acosta: Doctor Birx, with a very serious warning from the Coronavirus briefing, says she can see in the data that Americans are not fol…RT @SenToddYoung: More evidence that we must not only hold China accountable, but go on offense against the Chinese Communist Party as it s…RT @abc730: #Coronavirus has made it impossible for some children to see their #grandparents in person. Hundreds of kids sent #abc730 video…RT @philipskaggs: We simply do not have a functioning federal government. Save us governors! https://t.co/lcyyV6Y7RA https://t.co/ZeUuhTXlvXRT @CNN: Former Democratic presidential candidate Andrew Yang said it is a "heartbreaking phenomenon" that Asian Americans have been the ta…WALRC's first regional virtual discussion group happening right now. We've got 22 Manypeaks locals plus… https://t.co/BkC35ucv6XRT @JRubinBlogger: Gov of Florida, Texas, Missouri and Georgia will have thousands of dead on their heads. Rightwing ideologues resisted sc…RT @SamanthaJPower: For those arguing authoritarian systems better at managing #covid, see Belarus, Turkmenistan etc. Lukashenko has kept o…RT @josungkim: The spark that ignited flame: How two young female journalists uncovered and exposed ongoing online sexual abuse of women an…RT @TomFitton: Urgent: India approved #Hydroxycloroquine as prophylactic for at risk groups. @RealDonaldTrump should push to deploy drug on…@bfraser747 This has to be one of the best stories not only did he beat the Coronavirus but he survived the Spanish… https://t.co/7etxTP9AQjRT @raizawilson: In a time when bad decisions may spark a larger response, let’s do what’s right ❤️RT @KamalaHarris: Fifty days ago I attended a Homeland Security committee meeting about the coronavirus—and no current Trump administration…RT @SABCNewsOnline: Eastern Cape Premier Oscar Mabuyane has established an Economic Commission to assist the business sector after the coro…@fawadchaudhry @hecpkofficial @ImranKhanPTI @OfficialDGISPR
# Biomedical  PhD Scientists, Biomedical Engineers(PEC)… https://t.co/3zzZorzUfyRT @margotroosevelt: She's a single mother, a hotel housekeeper, one of millions laid off in the coronavirus pandemic. Mr. C. Beverly Hills…Top pediatricians answering viewers' queries on children amid Coronavirus; Tweet your questions using… https://t.co/3jlbLyjRG1RT @CuomoPrimeTime: “What good is it to say you are praying for [coronavirus patients] and there are angels on Earth if you are not doing e…RT @DonaldJTrumpJr: Yikes! Why have the media not focused on this one?
#
# DCCC Chair Unloaded $50K in Stock After Coronavirus Briefing https…https://t.co/RUlT2ighq3
# This makes me sadRT @az_valentine: Time to Re-Hire tht "Psychic News Lady @trish_regan .. @GovMikeHuckabee @WhiteHouse @CW33433 @PhxKen @cvpayne @BillPerima…RT @KenRoth: Cambodia's PM Hun Sen is pushing for a "state of emergency" which, under the guise of fighting the coronavirus, would transfor…RT @nancylevine: Last night, @FoxNews rejected this ad called “Crisis Comes." Here’s the ad #FoxNews doesn’t want you to see. #covid19 #cor…RT @GordonGChang: This makes it official: #Canada has become #China's newest colony. #coronavirus #PattyHajdu #JustinTrudeauRT @AFPphoto: #Coronavirus #COVID19 #Iraq
#  This combination of pictures shows medical staffers on the frontline treating patients at al-Ha…RT @RVAwonk: “FL Gov. Ron DeSantis overruled local counties’ power to ban large religious gatherings amid the coronavirus pandemic, carving…RT @AliVelshi: Muscle aches, extreme fatigue: Coronavirus symptoms go beyond fever and cough https://t.co/XHHxAmD3uFRT @RepDougCollins: Rather than calling for a commission to investigate @realDonaldTrump’s coronavirus response, Adam Schiff should focus o…RT @Yamiche: The governor of Georgia says he just learned in the last 24 hrs that people without symptoms can spread coronavirus.
#
# Yet, for…RT @glocalreporting: Social distancing is impossible in #Prisons, medical care poor. Our @derspiegel report on the threat of a global #coro…RT @jules_su: Does anyone else feel like they’re stuck in the movie Groundhog Day, except every day is 9/11.RT @KamalaHarris: Fifty days ago I attended a Homeland Security committee meeting about the coronavirus—and no current Trump administration…RT @JaneMundon: 70 days ago....GREGG BRADEN: CORONAVIRUS TRUTH &amp; FICTION - What The World Needs To Know... https://t.co/7cEX5zAUFQ via @YouTubeRT @HawaiiDelilah: Never forget that with more competent leadership from the president, this coronavirus pandemic could have had a managed…RT @BradleyWhitford: War criminals pardoned. War heroes fired. https://t.co/rq2RFl2Ym0“This” is how it’s done!RT @funder: This doctor deserves an award for calling out Trump’s failed coronavirus response on Fox News https://t.co/8vu9dsqVbhRT @KaviyaNow: Nice movie
#
# #Karnan
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:23:00
# -------------------------------------------
# ('#coronavirus', 59)
# ('#covid19', 13)
# ('#ishaoutreach', 5)
# ('#coronavirus.', 4)
# ('#covidー19', 4)
# ('#lockdown', 3)
# ('#coronavirus,', 3)
# ('#selflessservicebydssvolunteers', 3)
# ('#modivideomessage', 3)
# ('#ayan', 3)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:23:00
# -------------------------------------------
# ('movie', 45, '2020-04-03 05:23:00')
# ('ai', 2, '2020-04-03 05:23:00')
# ('coronavirus', 221, '2020-04-03 05:23:00')
# ('data', 12, '2020-04-03 05:23:00')
# ('spark', 4, '2020-04-03 05:23:00')
#
# -------------------------------------------
# Time: 2020-04-03 05:24:00
# -------------------------------------------
# https://t.co/ierWzGLfeTRT @alientyong: JW: Statue/AI 👉🏻 Statue-like man
# MK: He was quiet 👉🏻 He’s kinda a cutie
# HC: ‘Do you want water?’ 👉🏻 Maker of the living roo…RT @NorbertElekes: Coronavirus pandemic:
#
# From 1 to 500,000 cases: 19 weeks
#
# From 500,000 to 1,000,000 cases: 1 weekRT @Jadaa_denise: at the bottom in big red letters says “coronavirus response” and yet he’s talking about being popular on facebook. we are…RT @HillaryClinton: Millions of people have lost their employer-tied health care over the last two weeks because of the pandemic.
#
# It's an…I phone nine , gotta roll it back
#
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:24:00
# -------------------------------------------
# ('#coronavirus', 124)
# ('#covid19', 32)
# ('#covidー19', 10)
# ('#selflessservicebydssvolunteers', 9)
# ('#coronavirus.', 8)
# ('#covid19pandemic', 7)
# ('#ishaoutreach', 7)
# ('#lockdown', 6)
# ('#coronavirus,', 6)
# ('#china', 6)
# ...
# -------------------------------------------
# Time: 2020-04-03 05:24:00
# -------------------------------------------
# ('movie', 63, '2020-04-03 05:24:00')
# ('ai', 8, '2020-04-03 05:24:00')
# ('coronavirus', 277, '2020-04-03 05:24:00')
# ('data', 12, '2020-04-03 05:24:00')
# ('spark', 1, '2020-04-03 05:24:00')
#
# -------------------------------------------
# Time: 2020-04-03 05:25:00
# -------------------------------------------
# 3/17 1…RT @DougDavidsonYR: God bless your soul.RT @JoyAnnReid: "As companies nationwide look for relief, the Trump Organization has talked with Deutsche Bank and a Florida county about d…RT @vanitaguptaCR: Jared Kushner. The Patron Saint of Unqualified White Men. https://t.co/29X3cacv29RT @maddow: Milwaukee Journal-Sentinel editorial against the (astonishing) plan by Wisconsin to go ahead with its primary next week:
#
# "As c…RT @SafetyPinDaily: The Evil Tucked Into the $2 Trillion Coronavirus Stimulus Bill || Via: Time https://t.co/hkZsCwSJeGRT @nazmaaman: Hi there @aamir_khan I'm sure you would want to know what @BabitaPhogat the otherwise unknown entity, whom you brought to li…RT @warmfourloko: well damn jackie i can’t control the coronavirusRT @emardoh: Kinda crazy that standardized testing can be thrown away just like that. It’s almost as if... dare I say... they are a uselees…RT @MagentaPixie: They always say "X amount of people who tested positive for the coronavirus, have died" - This is likely true however it…LAPD officers will wear face masks, coverings as coronavirus precaution https://t.co/Rz2cu0dwYGRT @SJPFISH: Nancy Pelosi admits that Democrats "knew about" the Coronavirus outbreak before it happened ?
#
# But Pelosi &amp; the Do Nothing Dem…RT @wandascomics: 1 mouth until netflix release 'The Half of It' the first romcom cliche lesbian movie of the plataform, the director is al…RT @Vishj05: Now waiting for a Whatsapp message telling that how lighting diya in night will fight Coronavirus.
#
# #ModiVideoMessageRT @ryanstruyk: Reported US coronavirus deaths via @CNN:
#
# 4 weeks ago: 12 deaths
# 3 weeks ago: 41 deaths
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:25:00
# -------------------------------------------
# ('#coronavirus', 207)
# ('#covid19', 50)
# ('#covidー19', 17)
# ('#coronavirus.', 13)
# ('#china', 13)
# ('#selflessservicebydssvolunteers', 12)
# ('#ishaoutreach', 12)
# ('#covid19pandemic', 11)
# ('#coronavirus,', 10)
# ('#ayan', 10)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:25:00
# -------------------------------------------
# ('movie', 67, '2020-04-03 05:25:00')
# ('ai', 11, '2020-04-03 05:25:00')
# ('coronavirus', 371, '2020-04-03 05:25:00')
# ('data', 4, '2020-04-03 05:25:00')
# ('spark', 1, '2020-04-03 05:25:00')
#
# -------------------------------------------
# Time: 2020-04-03 05:26:00
# -------------------------------------------
# Thank you all for taking COVID-19 seriously. The sacrifices y…RT @PressTV: Romina Salek, 14 year-old member of #Iran's national inline skating team, has resorted to indoor training at home during #coro…RT @tedlieu: Dear @SECNAV Modly: This is not a good look for you or for the @realDonaldTrump Administration. Looks like retaliation. Sugges…@fuuuckingpussy I love this movie ❤RT @TMZ: Man With Coronavirus Spits In Passenger's Face Before Dropping Dead https://t.co/7XIuHvPdnxRT @5stocksinto: 5 Indonesian Stocks Into Snacks https://t.co/f3xshJRUS8 #Indonesia #Food #Stocks #Investment #IDX #Snacks #Noodles #Indomi…@SirDemiface I mean people who's history the movie says it represents usually care.RT @FOX5Atlanta: The shelter in place order issued by Gov Kemp on Thursday is due to go into effect at 6pm today.
# Full coverage of the #cor…RT @eugenegu: Jared Kushner is helping lead the government’s coronavirus response while his brother Joshua Kushner is the co-founder of a d…RT @javimorgado: New: America’s top infectious disease expert, Dr. Anthony Fauci, said moments ago on CNN that the ENTIRE country should be…RT @KKeneally: These nurses have been working in pop-up testing clinics &amp; Acute Medical Respiratory Units across Australia – but then have…RT @JatNationalist: SHOOT THEM DEAD. This what Modi should've said regarding all the people who were throwing stones at our medical workers…RT @nalinisharma_: Doctors from Deen Dayal Upadhyay hospital confirm to me that some of the markaz patients brought into the hospital were…RT @NorbertElekes: Coronavirus update, New York:
#
# - 8,669 new cases in last 24 hours
# - 432 new deaths
# - 238,965 tested so far
# - 92,381 test…RT @GauravPandhi: Shahrukh Khan is so classy. He donated to PM-Cares fund to fight Coronavirus #Covid19 &amp; unlike others, he didn't publicis…RT @MOFA_Taiwan: Wow, can’t even utter “Taiwan” in the WHO? You should set politics aside in dealing with a pandemic. FYI @WHO, 450+ news r…RT @sentiyapaa: Masterstroke by PM Modi. One cannot stop admiring him. When billions of people will burn candles and diyas together, it'll…@VetMadeAmmo1 @TomFitton What you write isn't really an opinion. It is an illness. Your obsessive conspiracy theory… https://t.co/f1a2UgvrTWRT @RFaughnder: More details on Disney's impending furloughs, which come less than a week after the $2-trillion federal stimulus package ex…RT @Imamofpeace: Tablighi Jamaat was also involved in the burning of 59 Hindu Kar Sevaks in the 2002 Godhra train torching incident in Guja…RT @DelishDirection: You're a gem @iamsrk ♥️♥️RT @SabinaLamba: "No force stronger than r spirit&amp;enthusiasm"
# #PMModi's speech is abt messaging(we all together in this fight)so as 2 not l…OMG - Are you really that stupid, or do you think we are?
#
# FYI dumbass - Trump didn't 'shift' blame to the States.… https://t.co/YWF9gGp4zERT @Imamofpeace: Tablighi Jamaat was also involved in the burning of 59 Hindu Kar Sevaks in the 2002 Godhra train torching incident in Guja…RT @Drizzy: When the world is in shambles because of the coronavirus but a new Drake song drops https://t.co/Pv5Y6nhEJERT @VDHanson: A current myth alleges that America under the Trump administration is not leading the world fight against the coronavirus #CO…RT @PeterHotez: Great https://t.co/f1dITqfCOXCoronavirus: Wuhan residents told to stay inside and be vigilant – The Guardian https://t.co/79A18kQbeS https://t.co/GTmtshpZJXRT @catturd2: Since CNN and MSNBC won’t show Trump’s coronavirus briefings - the White House shouldn’t allow any of their reporters to atte…6.54 lakh migrant labourers from Jharkhand stranded amid lockdown https://t.co/dEkHowXCCR via @IndianExpressRT @tfipost: Beijing blitzkrieg: The virus and the most dangerous cover-up in modern history.
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:26:00
# -------------------------------------------
# ('#coronavirus', 298)
# ('#covid19', 79)
# ('#covidー19', 25)
# ('#coronavirus.', 20)
# ('#ai', 19)
# ('#china', 17)
# ('#covid19pandemic', 17)
# ('#selflessservicebydssvolunteers', 16)
# ('#iot', 16)
# ('#ishaoutreach', 16)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:26:00
# -------------------------------------------
# ('movie', 74, '2020-04-03 05:26:00')
# ('ai', 14, '2020-04-03 05:26:00')
# ('coronavirus', 514, '2020-04-03 05:26:00')
# ('data', 12, '2020-04-03 05:26:00')
# ('spark', 1, '2020-04-03 05:26:00')
#
# -------------------------------------------
# Time: 2020-04-03 05:27:00
# -------------------------------------------
# “We may be getting more than narcotics because th…RT @MFA_China: Slanders &amp; blame games cannot make up for lost time. More lies will only waste more time and cost more lives. People's lives…Always negative news. Always the worsts possibilities. Never positive. You are sad.RT @GetWisdomDude: Sometime Soon,
# Someone Will Tell The Families Of Coronavirus Patients, Doctors, Nurses &amp; Everyone On The Frontlines Of T…RT @ThePubliusUSA: Raise your hand if you agree that Jared Kushner has no business being on the coronavirus task force ✋
#  https://t.co/XhJM…🙏🏻🙏🏻God bless and protect our great leader 🙏🏻🙏🏻🙏🏻RT @fructosepapi: “funny how bitches turn into my fans”RT @CBSNews: "Shoot them dead": Philippine President Rodrigo Duterte orders police and military to kill citizens who defy coronavirus lockd…COVID-19 CORONAVIRUS PANDEMIC
# Last updated: April 02, 2020, 23:59 CET
# Coronavirus Cases: 1 014 943
# Deaths: 53 166
# R… https://t.co/8SO2XubOCiRT @AngrierWHStaff: He’s broke.
#
# He’s always been broke.
#
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:27:00
# -------------------------------------------
# ('#coronavirus', 398)
# ('#covid19', 104)
# ('#coronavirus.', 33)
# ('#covidー19', 31)
# ('#ai', 31)
# ('#china', 22)
# ('#iot', 22)
# ('#covid19pandemic', 21)
# ('#machinelearning', 21)
# ('#bigdata', 20)
# ...
# -------------------------------------------
# Time: 2020-04-03 05:27:00
# -------------------------------------------
# ('movie', 80, '2020-04-03 05:27:00')
# ('ai', 13, '2020-04-03 05:27:00')
# ('coronavirus', 496, '2020-04-03 05:27:00')
# ('data', 22, '2020-04-03 05:27:00')
#
# -------------------------------------------
# Time: 2020-04-03 05:28:00
# -------------------------------------------
# RT @vanitaguptaCR: Jared Kushner. The Patron Saint of Unqualified White Men. https://t.co/29X3cacv29RT @MRCRUZv3: THAT BITCH CAROLE BASKINRT @RexChapman: In Toronto, several tenants of a building were worried they couldn't pay their rent during the Coronavirus pandemic.
#
# Their…me and krys just watched sharkboy and lava girl it was the worst fucking movie ive ever watchedThe transmission rate for #coronavirus is 33% per day in an urban area without any lockdown or protection.Did a sim… https://t.co/VOig6O2KF3Mayo Clinic starts using autonomous vehicles to deliver coronavirus tests and medical supplies : #analytics… https://t.co/di85ReXiVuRT @spectatorindex: MYANMAR: Cardinal Muang Bo says China should apologise and pay compensation for coronavirus outbreakDoctors found a coronavirus patient who was contagious for 49 days https://t.co/W7Qm6OJic1 by @chris_writes @BGRRT @emardoh: Kinda crazy that standardized testing can be thrown away just like that. It’s almost as if... dare I say... they are a uselees…RT @colonelhogans: How’s Trumps one trillion dollars in tax cuts for business now? They took the tax cuts, spent it on share buy backs and…RT @WayneDupreeShow: Pelosi loses her cool when asked about ignoring Coronavirus in favor of her sham impeachment. She's well past her prim…RT @scott_tobias: This cannot be real life. https://t.co/GjFy256CqART @DailyCaller: DHS Suspends Increase In Guest Worker Visas After Tucker Carlson’s Segment https://t.co/MPByVRLp2CRT @tommytomtoyou: "Who controls the past controls the future.  Who controls the present controls the past." - George Orwell, 1984RT @BrookeSingman: EXCLUSIVE: @realDonaldTrump's campaign has been quietly calling local restaurants and ordering large amounts of food to…RT @josungkim: The spark that ignited flame: How two young female journalists uncovered and exposed ongoing online sexual abuse of women an…RT @EricMMatheny: What are we supposed to do, wait until nobody gets sick? You think coronavirus is bad, wait until you see a depression an…RT @sentiyapaa: Masterstroke by PM Modi. One cannot stop admiring him. When billions of people will burn candles and diyas together, it'll…RT @NikkiHaley: China has reported only 82,000 coronavirus cases &amp; 3300 deaths in a nation of 1.5 billion people.This is clearly not accura…Waiting for Whatsapp theories on how lighting diyas and switiching off cellphones for 9 minutes will kill. #coronavirus  #9baje9minuteRT @IndyPressLive: Do NOT #boycott3m.
#
# It’s was not 3M’s job to save us. 3M is just a company. It was Trump’s job to save us, and he screwe…RT @rapplerdotcom: In the late afternoon, all but one member of the clinic staff leaves for home. The man left behind is a 28-year-old jani…RT @IrishMarine94: @DanCrenshawTX I never thought a Navy Seal would behave like a Soviet propagandist - delegitimizing free speech, but her…RT @seanhannity: PELOSI: ‘Don’t Blame Impeachment’ for Coronavirus Outbreak, It Was ‘Self-Evident’ https://t.co/8XSxhbl9UHCurrently watching the Bratz movie..RT @munyale: Saddest and most heart wrenching movie I have ever seen. But worth it. Totally worth itRT @townhallcom: President Trump wasn't the one who dragged his feet for DAYS on the coronavirus relief bill. https://t.co/x8vWarfL6HThe Japanese government has decided to give 200,000 yen ($1,850) in cash to each household struggling with falling… https://t.co/nNWJf7i5HfRT @jimanfc1306: 『Weibo』
# 200324 | BTS_official
#
# [# ThisMonthsBTS #] Please continue to take care of us in the future O(∩_∩)O
# # Joined Weibo…RT @emardoh: Kinda crazy that standardized testing can be thrown away just like that. It’s almost as if... dare I say... they are a uselees…RT @the_hindu: The number of #coronavirus infections worldwide has hit 1 million, with more than 50,000 deaths, according to the tally kept…RT @whereverthesuns: When I see shit like this, it reminds me how vegetarians/ vegans honestly believe their food is cruelty free. You want…RT @SheriffEd_HCSO: Social distance *now*, or else when you catch the coronavirus, all the hospitals might be completely full."RT @OH_mes2: Yuehua Entertainment confirms one of their staff members was diagnosed with Coronavirus
#
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:28:00
# -------------------------------------------
# ('#coronavirus', 446)
# ('#covid19', 111)
# ('#covidー19', 37)
# ('#ai', 36)
# ('#coronavirus.', 35)
# ('#china', 27)
# ('#covid19pandemic', 24)
# ('#iot', 22)
# ('#machinelearning', 22)
# ('#bigdata', 21)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:28:00
# -------------------------------------------
# ('movie', 45, '2020-04-03 05:28:00')
# ('ai', 3, '2020-04-03 05:28:00')
# ('coronavirus', 180, '2020-04-03 05:28:00')
# ('spark', 1, '2020-04-03 05:28:00')
# ('data', 3, '2020-04-03 05:28:00')
#
# -------------------------------------------
# Time: 2020-04-03 05:29:00
# -------------------------------------------
# RT @_xFenrir: Summoning circle, hope it works
#
#                    🕯      🕯
#            🕯                       🕯…RT @JamilaAmarah: GIVE THEM WHATEVER THEY WANTRT @nsouthern95: Medical Expert Sees 'Beginning of the End' in Coronavirus Fight with New Treatment Results https://t.co/nhuj9ep1PyRT @Amy_Siskind: And here's the man running our coronavirus response:
# "The senior official described the Kushner team as a “frat party” tha…@PaulineHansonOz Please tell me we can fight this?
# https://t.co/xBAPwTtPaoRT @Imamofpeace: India confronts its first coronavirus ‘super-spreader’ — a Islamist fundamentalist brainwashing missionary group with ties…RT @johnlegend: "Kushner has succeeded at exactly three things in his life. He was born to the right parents, married well and learned how…RT @dailyhaechan: haechan expressing him self with hashtags:
#
# # fullsun
# # sunflower
# # gamer
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:29:00
# -------------------------------------------
# ('#coronavirus', 524)
# ('#covid19', 128)
# ('#coronavirus.', 46)
# ('#covidー19', 41)
# ('#ai', 37)
# ('#china', 31)
# ('#covid19pandemic', 27)
# ('#bigdata', 24)
# ('#iot', 24)
# ('#selflessservicebydssvolunteers', 23)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:29:00
# -------------------------------------------
# ('movie', 64, '2020-04-03 05:29:00')
# ('ai', 6, '2020-04-03 05:29:00')
# ('coronavirus', 321, '2020-04-03 05:29:00')
# ('data', 8, '2020-04-03 05:29:00')
# ('spark', 1, '2020-04-03 05:29:00')
#
# -------------------------------------------
# Time: 2020-04-03 05:30:00
# -------------------------------------------
# RT @RexChapman: I’m definitely here for old folks challenging other old folks to chug a beer in their garages during this Coronavirus pande…Hydroxychloroquine rated 'most effective therapy' by doctors for coronavirus: Global survey
#
# https://t.co/Id2AhavckQRT @ewarren: People experiencing homelessness are particularly vulnerable during this crisis. I've introduced a bill with @AyannaPressley a…RT @Vastuullisuus: #US #eases# ban on #gay #blood donors amid coronavirus. https://t.co/w6y17m6v87RT @David_Leavitt: 🚨 🚨 🚨  ATTENTION 🚨 🚨 🚨
#
# #coronavirus is being spread at grocery stores and can live on food packaging for THREE DAYS.…RT @BaronStrucker: Another video of a non-white thinking they are spreading #CoronaVirus
#
# Thanks to @burstmazzter for video
#
# #Coronavirustr…The #Covid45 #ClusterTrump continues...
#
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:30:00
# -------------------------------------------
# ('#coronavirus', 612)
# ('#covid19', 158)
# ('#coronavirus.', 53)
# ('#covidー19', 45)
# ('#ai', 38)
# ('#china', 34)
# ('#covid19pandemic', 32)
# ('#selflessservicebydssvolunteers', 26)
# ('#bigdata', 25)
# ('#iot', 25)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:30:00
# -------------------------------------------
# ('movie', 70, '2020-04-03 05:30:00')
# ('ai', 5, '2020-04-03 05:30:00')
# ('coronavirus', 329, '2020-04-03 05:30:00')
# ('spark', 3, '2020-04-03 05:30:00')
# ('data', 8, '2020-04-03 05:30:00')
# -------------------------------------------
# Time: 2020-04-03 05:31:00
# -------------------------------------------
# RT @tehseenp: The questions that should have been asked in the #ModiVideoMessage .
# #COVID19Pandemic
# The #ModiVirus is MORE dangerous than…Coronavirus Anxiety Is Real: How To Stay Mentally Strong During The COVID-19 Pandemic - Dr. Judson Brewer - London… https://t.co/KYGE2sXcuZBreaking News #danielnewman #marktakano #nancypelosi #kencalvert #riversidecounty #associatedpress #nbc #cbs #pbs… https://t.co/YbMWVcPDLsWhat's Your Age Releasing the Period Of Ayan Movie 😉
#
# #11YearsOfAyanThank youRT The_Real_Fly: The number of commercial real estate borrowers who requested debt relief during the escalation of the coronavirus outbrea…RT @CNN: Washington Gov. Jay Inslee is calling for a national strategy to combat the coronavirus pandemic.
#
# "This is a national problem. I…RT @RobertDeNiroUS: -Who did this? 😅 #coronavirus https://t.co/kCRaPHuLr5Try it by yourself!
# Never forward anything before verifying whether it is genuine or fake, fake news creates a nega… https://t.co/Wp9tCe7cOjRT @Vishj05: Now waiting for a Whatsapp message telling that how lighting diya in night will fight Coronavirus.
#
# #ModiVideoMessagethis will not work! this gov is still leaving churches OPEN!! IT WILL NoT stop out there. We should demand that no… https://t.co/NeBThXdwLeRT @prayingmedic: The Navy relieved Brett Crozier, the commander of the aircraft carrier Theodore Roosevelt, after he wrote a letter asking…RT @DavidLat: I was at @nyulangone hospital for 17 days in all -- including about a week in critical condition in the ICU, breathing throug…In the midst of a coronavirus outbreak, an unlikely hero. More on how a tablet-on-wheels robot is helping doctors t… https://t.co/5E0PefjT5ORT @INCIndia: Coronavirus pandemic has also brought with itself an economic disaster for the Indian economy which was already dwindling. Th…RT @Emily_Baum: NEW: Two months before the novel coronavirus likely began spreading in Wuhan, the Trump administration ended a $200-million…RT @funder: Jared Kushner is now talking at the coronavirus press conference. MSNBC cut away the second Kushner got to the podium. #StopAir…RT @DailyMirror: Coronavirus 'may cause brain damage' as swelling found in 'confused' patients https://t.co/MNWTCTz4qm https://t.co/i8reDnj…Coronavirus: How to understand the death toll - BBC News #covid19 https://t.co/pL6X7hhHjjRT @NewYorker: The coronavirus was not of President Trump’s making, but his government’s incoherent, disorganized response to it was utterl…RT @KamalaHarris: Fifty days ago I attended a Homeland Security committee meeting about the coronavirus—and no current Trump administration…RT @IndyPressLive: Do NOT #boycott3m.
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:31:00
# -------------------------------------------
# ('#coronavirus', 669)
# ('#covid19', 174)
# ('#coronavirus.', 55)
# ('#covidー19', 45)
# ('#ai', 45)
# ('#china', 35)
# ('#covid19pandemic', 35)
# ('#bigdata', 29)
# ('#selflessservicebydssvolunteers', 29)
# ('#iot', 29)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:31:00
# -------------------------------------------
# ('movie', 42, '2020-04-03 05:31:00')
# ('ai', 4, '2020-04-03 05:31:00')
# ('coronavirus', 175, '2020-04-03 05:31:00')
# ('data', 4, '2020-04-03 05:31:00')
#
# -------------------------------------------
# Time: 2020-04-03 05:32:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:32:00
# -------------------------------------------
# ('#coronavirus', 669)
# ('#covid19', 174)
# ('#coronavirus.', 55)
# ('#covidー19', 45)
# ('#ai', 45)
# ('#china', 35)
# ('#covid19pandemic', 35)
# ('#bigdata', 29)
# ('#selflessservicebydssvolunteers', 29)
# ('#iot', 29)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:32:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:33:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:33:00
# -------------------------------------------
# ('#coronavirus', 669)
# ('#covid19', 174)
# ('#coronavirus.', 55)
# ('#covidー19', 45)
# ('#ai', 45)
# ('#china', 35)
# ('#covid19pandemic', 35)
# ('#bigdata', 29)
# ('#selflessservicebydssvolunteers', 29)
# ('#iot', 29)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:33:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:34:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:34:00
# -------------------------------------------
# ('#coronavirus', 669)
# ('#covid19', 174)
# ('#coronavirus.', 55)
# ('#covidー19', 45)
# ('#ai', 45)
# ('#china', 35)
# ('#covid19pandemic', 35)
# ('#bigdata', 29)
# ('#selflessservicebydssvolunteers', 29)
# ('#iot', 29)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:34:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:35:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:35:00
# -------------------------------------------
# ('#coronavirus', 669)
# ('#covid19', 174)
# ('#coronavirus.', 55)
# ('#covidー19', 45)
# ('#ai', 45)
# ('#china', 35)
# ('#covid19pandemic', 35)
# ('#bigdata', 29)
# ('#selflessservicebydssvolunteers', 29)
# ('#iot', 29)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:35:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:36:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:36:00
# -------------------------------------------
# ('#coronavirus', 669)
# ('#covid19', 174)
# ('#coronavirus.', 55)
# ('#covidー19', 45)
# ('#ai', 45)
# ('#china', 35)
# ('#covid19pandemic', 35)
# ('#bigdata', 29)
# ('#selflessservicebydssvolunteers', 29)
# ('#iot', 29)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:36:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:37:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:37:00
# -------------------------------------------
# ('#coronavirus', 669)
# ('#covid19', 174)
# ('#coronavirus.', 55)
# ('#covidー19', 45)
# ('#ai', 45)
# ('#china', 35)
# ('#covid19pandemic', 35)
# ('#bigdata', 29)
# ('#selflessservicebydssvolunteers', 29)
# ('#iot', 29)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:37:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:38:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:38:00
# -------------------------------------------
# ('#coronavirus', 669)
# ('#covid19', 174)
# ('#coronavirus.', 55)
# ('#covidー19', 45)
# ('#ai', 45)
# ('#china', 35)
# ('#covid19pandemic', 35)
# ('#bigdata', 29)
# ('#selflessservicebydssvolunteers', 29)
# ('#iot', 29)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:38:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:39:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:39:00
# -------------------------------------------
# ('#coronavirus', 669)
# ('#covid19', 174)
# ('#coronavirus.', 55)
# ('#covidー19', 45)
# ('#ai', 45)
# ('#china', 35)
# ('#covid19pandemic', 35)
# ('#bigdata', 29)
# ('#selflessservicebydssvolunteers', 29)
# ('#iot', 29)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:39:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:40:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:40:00
# -------------------------------------------
# ('#coronavirus', 669)
# ('#covid19', 174)
# ('#coronavirus.', 55)
# ('#covidー19', 45)
# ('#ai', 45)
# ('#china', 35)
# ('#covid19pandemic', 35)
# ('#bigdata', 29)
# ('#selflessservicebydssvolunteers', 29)
# ('#iot', 29)
# ...
# -------------------------------------------
# Time: 2020-04-03 05:40:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:41:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:41:00
# -------------------------------------------
# ('#coronavirus', 669)
# ('#covid19', 174)
# ('#coronavirus.', 55)
# ('#covidー19', 45)
# ('#ai', 45)
# ('#china', 35)
# ('#covid19pandemic', 35)
# ('#bigdata', 29)
# ('#selflessservicebydssvolunteers', 29)
# ('#iot', 29)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:41:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:42:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:42:00
# -------------------------------------------
# ('#coronavirus', 669)
# ('#covid19', 174)
# ('#coronavirus.', 55)
# ('#covidー19', 45)
# ('#ai', 45)
# ('#china', 35)
# ('#covid19pandemic', 35)
# ('#bigdata', 29)
# ('#selflessservicebydssvolunteers', 29)
# ('#iot', 29)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:42:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:43:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-04-03 05:43:00
# -------------------------------------------
# ('#coronavirus', 669)
# ('#covid19', 174)
# ('#coronavirus.', 55)
# ('#covidー19', 45)
# ('#ai', 45)
# ('#china', 35)
# ('#covid19pandemic', 35)
# ('#bigdata', 29)
# ('#selflessservicebydssvolunteers', 29)
# ('#iot', 29)
# ...
#
# -------------------------------------------
# Time: 2020-04-03 05:43:00
# -------------------------------------------
#
# Running Finished.
# Saved To BigQuery Finished.

# %%
sc.stop()
